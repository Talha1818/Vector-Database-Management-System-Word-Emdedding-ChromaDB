# %% [markdown]
# <a href="https://colab.research.google.com/github/Talha1818/Vector-Database-Management-System-Word-Emdedding-ChromaDB/blob/master/Pipeline_VectorDB_ChromaDB_LangChain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
file_path = "/content/drive/MyDrive/Annotation Folder/Final_Text_Dataset_30_May_2023.csv"
df = pd.read_csv(file_path)
df = df[df['token'].isin([85,100,77,116,90])][['text', 'token']]
df.head()
# Out:
#                                                    text  token
# 477   Loan #: 224370418\nBorrower: Ashok Linganna, R...   77.0
# 622   . . a NEM, Inc. dba NFM Lending\n\u20ac NFM Le...  100.0
# 743   |\nACKNOWLEDGMENT OF RECEIPT OF\nAPPRAISAL REP...  100.0
# 803   Loan Number: 47065\n\nDate: MARCH 25, 2022\n\n...  100.0
# 1227  Acknowledgement of Receipt of Appraisal\nLoan ...  100.0

# %%
df.to_csv("data.csv", index=False)

# %%
# !pip install --upgrade sqlalchemy -q

# %%
from sqlalchemy import create_engine
import sqlite3

# %%
def savePandasDataSqlFormat(databaseName='talha.db', TableName='transdata'):
  # Specify the SQLite database file path
  sqlite_file_path = databaseName

  # Create the SQLite database engine
  engine = create_engine(f'sqlite:///{sqlite_file_path}', echo=False)

  # Save the DataFrame to the SQLite database
  df.to_sql(name=TableName, con=engine, if_exists='replace', index=False)
  print(f"Table `{TableName}` saved in `{databaseName}` Database")

# %%
def checkAllTableNameInDatabase(con):
  # Create a cursor to execute SQL queries
  cursor = con.cursor()

  # Use the cursor to query the 'sqlite_master' table to get the table names
  cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
  table_names = cursor.fetchall()

  # Close the cursor and the connection
  cursor.close()
  # con.close()

  # Display the table names
  print("Table Names:")
  for table in table_names:
      print(table[0])

# %%
def loadSqlDatabase(databaseName='talha.db', TableName='transdata'):
  # create a connection
  con = sqlite3.connect(databaseName)
  checkAllTableNameInDatabase(con)

  data = pd.read_sql_query(f'Select * from {TableName};', con)
  con.close()
  return data

# %%
databaseName = 'talha.db'
TableName = 'transdata'
savePandasDataSqlFormat(databaseName=databaseName, TableName=TableName)
# Out:
# Table `transdata` saved in `talha.db` Database

# %%
data = loadSqlDatabase(databaseName=databaseName, TableName=TableName)
# Out:
# Table Names:
# transdata

# %%
data.head()
# Out:
#                                                 text  token
# 0  Loan #: 224370418\nBorrower: Ashok Linganna, R...   77.0
# 1  . . a NEM, Inc. dba NFM Lending\n\u20ac NFM Le...  100.0
# 2  |\nACKNOWLEDGMENT OF RECEIPT OF\nAPPRAISAL REP...  100.0
# 3  Loan Number: 47065\n\nDate: MARCH 25, 2022\n\n...  100.0
# 4  Acknowledgement of Receipt of Appraisal\nLoan ...  100.0

# %%
# !pip install pymongo

# %%
# import pymongo

# %%
# # Convert the DataFrame to a list of dictionaries
# data_list = df.to_dict(orient='records')

# # Specify MongoDB connection details (Replace 'your_connection_string' with your actual MongoDB connection string)
# connection_string = 'mongodb+srv://talha:<password>@cluster0.6pub7ng.mongodb.net/'
# client = pymongo.MongoClient(connection_string)

# # Specify the database and collection name
# db_name = 'talha'
# collection_name = 'transdataData'

# %%
# # Insert the data_list into the specified collection
# db = client[db_name]
# collection = db[collection_name]
# collection.insert_many(data_list)

# %%
# import pymongo
# import pandas as pd
# import json
# from bson import ObjectId  # Import ObjectId from pymongo library

# if __name__ == '__main__':
#     # Connect to the MongoDB server
#     connection_string = 'mongodb+srv://talha:q9Et2KPYsTQktyWQ@cluster0.6pub7ng.mongodb.net/'
#     client = pymongo.MongoClient(connection_string)

#     # Access the desired database and collection
#     db = client['talha2']
#     collection = db['transdata']

#     # Query data from the collection and store it in a cursor
#     cursor = collection.find()

#     # Convert the cursor to a list of dictionaries
#     data_list = list(cursor)
#     print(type(data_list))

#     # Specify the filename for the JSON file
#     json_filename = 'mongoDB.json'

#     # Custom serialization function for ObjectId
#     def custom_json_encoder(o):
#         if isinstance(o, ObjectId):
#             return str(o)  # Convert ObjectId to its string representation
#         raise TypeError(f"Object of type {o.__class__.__name__} is not JSON serializable")


#     # Save the data_list as JSON to the file with custom serialization
#     with open(json_filename, 'w') as json_file:
#         json.dump(data_list, json_file, indent=4, default=custom_json_encoder)

#     df = pd.DataFrame(data_list)[['clean_text', 'token']]
#     print(df.head())

# %%
# Specify the filename for the JSON file
json_filename = 'mongoDB.json'

# Read the JSON file into a pandas DataFrame
df_mango = pd.read_json(json_filename)
df_mango.head()
# Out:
#                         _id  \
# 0  64b8c16f65d330e0647953e6
# 1  64b8c16f65d330e0647953e7
# 2  64b8c16f65d330e0647953e8
# 3  64b8c16f65d330e0647953e9
# 4  64b8c16f65d330e0647953ea
#
#                                           clean_text  token
# 0  loan borrower ashok linganna regina linganna p...     77
# 1  nem inc dba nfm lending uac nfm lending compan...    100
# 2  acknowledgment receipt appraisal report wark l...    100
# 3  loan number date march lender amres corporatio...    100
# 4  acknowledgement receipt appraisal loan number ...    100

# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285398 sha256=061c7f6c30bf71d311c34a904b1d46b4e3de4de89565105e50fe0c3325164d90
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession

# Create a SparkSession (you only need to do this once in your application)
spark = SparkSession.builder.appName("HandleData").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://60d89c54e14c:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>HandleData</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Replace 'your_file.csv' with the actual path to your CSV file
csv_file_path = 'data.csv'

# Read the CSV file into a PySpark DataFrame
df_spark = spark.read.csv(csv_file_path, header=True, inferSchema=True)
df_spark
# Out:
# DataFrame[text: string, token: string]

# %%
df_spark.show()
# Out:
# +--------------------+--------------------+
# |                text|               token|
# +--------------------+--------------------+
# |Loan #: 224370418...|                77.0|
# |. . a NEM, Inc. d...|               100.0|
# ||\nACKNOWLEDGMENT...|               100.0|
# |Loan Number: 4706...|               100.0|
# |Acknowledgement o...|               100.0|
# ||\n.\n|\n\nLoan N...|               100.0|
# |Loan #: 224314404...|                77.0|
# |Loan #: 224357401...|                77.0|
# |ACKNOWLEDGMENT OF...|               100.0|
# |Acknowledgment of...|               100.0|
# |"BORROWER ACKNOWL...| allowing you at ...|
# |".\nGENERAL DISCL...| In accordance wi...|
# |7. Under the Equa...|                90.0|
# |Insurance Company...|                90.0|
# |ia CALIBER\naes H...|               100.0|
# |Acknowledgment of...|               100.0|
# |"ee NFM, Inc. dba...| Sm. a. 23 E. Kin...|
# |Loan Number: 1916...|               100.0|
# ...

# %%
df_spark.select('token').show()
# Out:
# +-----+
# |token|
# +-----+
# | 77.0|
# |100.0|
# |100.0|
# |100.0|
# |100.0|
# |100.0|
# | 77.0|
# | 77.0|
# |100.0|
# |100.0|
# |100.0|
# | 90.0|
# | 90.0|
# | 90.0|
# |100.0|
# |100.0|
# |100.0|
# |100.0|
# | 77.0|
# |100.0|
# +-----+
# only showing top 20 rows

# %%
# Replace 'column_name' with the actual name of the column you want to retrieve
rows = df_spark.collect()

# Now you can iterate over the rows as a list of Rows
for row in rows:
    # Access the elements of each row using the column names
    print(f"Row: {row['token']}")
# Out:
# Row: 77.0
# Row: 100.0
# Row: 100.0
# Row: 100.0
# Row: 100.0
# Row: 100.0
# Row: 77.0
# Row: 77.0
# Row: 100.0
# Row: 100.0
# Row: 100.0
# Row: 90.0
# Row: 90.0
# Row: 90.0
# Row: 100.0
# Row: 100.0
# Row: 100.0
# Row: 100.0
# Row: 77.0
# Row: 100.0
# Row: 90.0
# Row: 90.0
# Row: 90.0
# Row: 100.0
# Row: 77.0
# Row: 100.0
# Row: 90.0
# Row: 90.0
# Row: 90.0
# Row: 100.0
# Row: 77.0
# Row: 77.0
# Row: 77.0
# Row: 77.0
# Row: 77.0
# Row: 77.0
# Row: 100.0
# Row: 100.0
# Row: 77.0
# Row: 77.0
# Row: 100.0
# Row: 90.0
# Row: 90.0
# Row: 90.0
# Row: 77.0
# Row: 77.0
# Row: 77.0
# Row: 100.0
# Row: 77.0
# Row: 77.0
# Row: 77.0
# Row: 77.0
# Row: 77.0
# Row: 77.0
# Row: 100.0
# Row: 85.0
# Row: 85.0
# Row: 90.0
# Row: 90.0
# Row: 90.0
# Row: 100.0
# Row: 100.0
# Row: 77.0
# Row: 77.0
# Row: 77.0
# Row: 100.0
# Row: 77.0
# Row: 100.0
# Row: 100.0
# Row: 77.0
# Row: 100.0
# Row: 100.0
# Row: 100.0
# Row: 77.0
# Row: 116.0
# Row: 85.0
# Row: 85.0
# Row: 90.0
# Row: 90.0
# Row: 90.0
# ...

# %%
# Select the first 30 rows from the DataFrame
selected_rows_spark = df_spark.limit(30)
selected_rows_spark.show()
# Out:
# +--------------------+-----+
# |          clean_text|token|
# +--------------------+-----+
# |loan borrower ash...| 77.0|
# |nem inc dba nfm l...|100.0|
# |acknowledgment re...|100.0|
# |loan number date ...|100.0|
# |acknowledgement r...|100.0|
# |loan number date ...|100.0|
# |loan borrower cya...| 77.0|
# |loan borrower cya...| 77.0|
# |acknowledgment re...|100.0|
# |acknowledgment re...|100.0|
# |borrower acknowle...|100.0|
# |general disclosur...| 90.0|
# |equal credit oppo...| 90.0|
# |insurance company...| 90.0|
# |caliber aes home ...|100.0|
# |acknowledgment re...|100.0|
# |nfm inc dba nfm l...|100.0|
# |loan number date ...|100.0|
# |loan borrower jef...| 77.0|
# |borrower acknowle...|100.0|
# +--------------------+-----+
# only showing top 20 rows

# %%
# from pyspark.sql import SparkSession

# def loadSqlDatabaseToSpark(databaseName='talha.db', tableName='transdata'):
#     # Create a SparkSession (you only need to do this once in your application)
#     spark = SparkSession.builder.appName("LoadSqlDatabaseToSpark").getOrCreate()

#     # Read data from the SQLite database into a PySpark DataFrame
#     data_spark = spark.read.format("jdbc") \
#         .option("url", f"jdbc:sqlite:{databaseName}") \
#         .option("dbtable", tableName) \
#         .load()

#     # Stop the SparkSession (don't forget to do this to release resources)
#     spark.stop()

#     return data_spark

# databaseName = 'talha.db'
# tableName = 'transdata'
# data_spark = loadSqlDatabaseToSpark(databaseName=databaseName, tableName=tableName)

# %%
# read the mangoDB csv file
csv_file_path = '/content/talha2.transdata.csv'

# Read the CSV file into a PySpark DataFrame
df_spark = spark.read.csv(csv_file_path, header=True, inferSchema=True)
df_spark
# Out:
# DataFrame[_id: string, clean_text: string, token: int]

# %%
df_spark.show()
# Out:
# +--------------------+--------------------+-----+
# |                 _id|          clean_text|token|
# +--------------------+--------------------+-----+
# |64b8c16f65d330e06...|loan borrower ash...|   77|
# |64b8c16f65d330e06...|nem inc dba nfm l...|  100|
# |64b8c16f65d330e06...|acknowledgment re...|  100|
# |64b8c16f65d330e06...|loan number date ...|  100|
# |64b8c16f65d330e06...|acknowledgement r...|  100|
# |64b8c16f65d330e06...|loan number date ...|  100|
# |64b8c16f65d330e06...|loan borrower cya...|   77|
# |64b8c16f65d330e06...|loan borrower cya...|   77|
# |64b8c16f65d330e06...|acknowledgment re...|  100|
# |64b8c16f65d330e06...|acknowledgment re...|  100|
# |64b8c16f65d330e06...|borrower acknowle...|  100|
# |64b8c16f65d330e06...|general disclosur...|   90|
# |64b8c16f65d330e06...|equal credit oppo...|   90|
# |64b8c16f65d330e06...|insurance company...|   90|
# |64b8c16f65d330e06...|caliber aes home ...|  100|
# |64b8c16f65d330e06...|acknowledgment re...|  100|
# ...

# %%
# Get the number of rows
num_rows = df_spark.count()

# Get the number of columns
num_columns = len(df_spark.columns)

# Print the shape (number of rows and columns)
print(f"Shape of DataFrame: ({num_rows}, {num_columns})")
# Out:
# Shape of DataFrame: (1006, 3)

# %%
df_spark.columns
# Out:
# ['_id', 'clean_text', 'token']

# %%
import pandas as pd

# Assuming you already have the DataFrame 'df_pandas'
memory_usage_bytes = df.memory_usage(deep=True).sum()
memory_usage_mb = memory_usage_bytes / (1024 * 1024)  # Convert bytes to MB
print(f"Memory usage of the DataFrame: {memory_usage_mb:.2f} MB")
# Out:
# Memory usage of the DataFrame: 0.50 MB

# %%
df_mongo = pd.read_csv("talha2.transdata.csv")
import pandas as pd

all_dataframes = [df, df_mongo]
names = ['csv1', 'csv2']

# This will give you a summary of memory usage for all DataFrames in the current session
pd.DataFrame([df.memory_usage(deep=True).sum() / (1024 * 1024) for df in all_dataframes],
             index=[name for name in names],
             columns=['Memory Usage (MB)'])
# Out:
#       Memory Usage (MB)
# csv1           0.498681
# csv2           1.067520

# %%
import pandas as pd
import time

# Assuming you already have the DataFrame 'df_pandas'

# Start the timer
start_time = time.time()

# Your DataFrame operation here, for example:
result = df_mongo.groupby('token').mean()

# Stop the timer
end_time = time.time()

# Calculate the execution time
execution_time_seconds = end_time - start_time
print(f"Execution time: {execution_time_seconds:.5f} seconds")
# Out:
# Execution time: 0.01015 seconds
# <ipython-input-33-9fcba6d6445f>:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result = df_mongo.groupby('token').mean()

# %%
# from pyspark.sql import SparkSession
# from pyspark.sql.functions import current_timestamp

# # Create a SparkSession (you only need to do this once in your application)
# spark = SparkSession.builder.appName("DataFrameMeasurements").getOrCreate()

# # Assuming you already have the DataFrame 'df_spark'

# # Record the start time
# start_time = df_spark.withColumn("start_time", current_timestamp())

# # Your DataFrame operation here, for example:
# result = df_spark.groupBy('token').avg()

# # Record the end time
# result = result.withColumn("end_time", current_timestamp())

# # Calculate the execution time in seconds
# execution_time_df = result.withColumn("execution_time", (result["end_time"].cast("long") - result["start_time"].cast("long")))

# # Display the execution time and other metrics
# execution_time_df.show()

# %% [markdown]
# # **ChromaDB + LangChain**

# %%
# !pip -q install langchain pypdf sentence_transformers InstructorEmbedding
# !pip install chromadb==0.3.26 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 21.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.1/256.1 kB 25.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 10.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 85.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 114.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 2.9 MB/s eta 0:00:00
# ...

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 0.0.240
# Summary: Building applications with LLMs through composability
# Home-page: https://www.github.com/hwchase17/langchain
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: aiohttp, async-timeout, dataclasses-json, langsmith, numexpr, numpy, openapi-schema-pydantic, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by:

# %%
# !wget -q https://www.dropbox.com/s/zoj9rnm7oyeaivb/new_papers.zip
# !unzip -q new_papers.zip -d new_papers

# %%
from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.llms import OpenAI
from langchain.chains import RetrievalQA
from langchain.document_loaders import TextLoader
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders import DirectoryLoader
from langchain.document_loaders.csv_loader import CSVLoader


from InstructorEmbedding import INSTRUCTOR
from langchain.embeddings import HuggingFaceInstructEmbeddings
# Out:
# /usr/local/lib/python3.10/dist-packages/InstructorEmbedding/instructor.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange

# %%
# # Load and process the text files
# # loader = TextLoader('single_text_file.txt')
# loader = DirectoryLoader('./new_papers/new_papers/', glob="./*.pdf", loader_cls=PyPDFLoader)

# documents = loader.load()

# %%
loader = CSVLoader(file_path='/content/data.csv')
documents = loader.load()

# %%
documents[1]
# Out:
# Document(page_content='text: . . a NEM, Inc. dba NFM Lending\\n\\u20ac NFM Lending A + (e! A \\u201c~ Company NMLS 2893\\n| Family of Lenders Sm me, em a a, 1524 Kings Highway\\n: Swedesboro, NJ 08085\\nMLO NMLS 95005\\nBORROWER APPRAISAL RECEIPT ACKNOWLEDGEMENT\\nBorrower(s): Matthew Alexander Resch Property 235 W Thompson St\\nAddress: Philadelphia PA 19122\\nDate: August 9, 2022 Loan Number: 23921040557\\nYou are entitled to receive a copy of any appraisal report that is obtained on your behalf, concerning your\\nsubject property, at least three business days prior to the closing of your loan. A copy of any and all such\\nappraisal reports (\\u201cappraisal report\\u2019) should have already been delivered to you, allowing you at least\\nthree business days to review it prior to the closing of your loan.\\nIf you wish to proceed with the loan closing, your signature will acknowledge either:\\n1. Your receipt of the appraisal report three or more business days prior to your loan cl
# ...

# %%
len(documents)
# Out:
# 503

# %%
#splitting the text into
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
texts = text_splitter.split_documents(documents)

# %%
texts[0]
# Out:
# Document(page_content='text: Loan #: 224370418\\nBorrower: Ashok Linganna, Regina Linganna\\nProperty Address: 1011 INDIAN CREEK LN\\nWYNNEWOOD, PENNSYLVANIA 19096\\nPlease be advised that this Agreement confirms that we have received funding authorization via funding number from\\nGUARANTEED RATE, INC. ,\\nand have successfully funded the above-mentioned borrower and all monies have been disbursed.\\nDanielle Seward\\nTricia ey Magrann\\nPrinted nayhe of Settlement Agent/Attorney\\n/ ] rd\\nigmaturd of Settlement Agent/Attorney\\nDate E\\nTITLE AGENT FUNDING CONFIRMATION AGREEMENT H\\nTAFCAMSC. 05/23/08 \\u2018% DocMagic\\nFe Be Be\\n\\x0c\ntoken: 77.0', metadata={'source': '/content/data.csv', 'row': 0})

# %%
len(texts)
# Out:
# 1346

# %%
from langchain.embeddings import HuggingFaceInstructEmbeddings

instructor_embeddings = HuggingFaceInstructEmbeddings(model_name="hkunlp/instructor-xl",
                                                      model_kwargs={"device": "cuda"})
# Out:
# ...
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %% [markdown]
# ## **create the DB**

# %%
# Embed and store the texts
# Supplying a persist_directory will store the embeddings on disk
persist_directory = 'db'

## Here is the nmew embeddings being used
embedding = instructor_embeddings

vectordb = Chroma.from_documents(documents=texts,
                                 embedding=embedding,
                                 persist_directory=persist_directory)

# %%
# persiste the db to disk
vectordb.persist()
vectordb = None

# %%
# Now we can load the persisted database from disk, and use it as normal.
vectordb = Chroma(persist_directory=persist_directory,
                  embedding_function=embedding)

# %% [markdown]
# ## **Make a retriever**

# %%
retriever = vectordb.as_retriever()

# %%
docs = retriever.get_relevant_documents("What is the NFM Lending?")

# %%
len(docs)
# Out:
# 4

# %%
docs[0]
# Out:
# Document(page_content='text: NFM, Inc. dba NFM Lending\\neS NEM Lending\\u2019 a | fe A \\u201c~ Company NMLS 2893\\nFaretiy Lanter a a 4 Trading Post Way\\nMedford Lakes, NJ 08055\\nMLO NMLS 13818\\neee sy\\n| BORROWER APPRAISAL RECEIPT ACKNOWLEDGEMENT\\nBorrower(s): Hoang T Luong Property 36 Crider Avenue\\nNinanghi T Tran Address: Moorestown NJ 08057\\nBao Thai Tran\\nDate: September 2, 2022 Loan Number. 35507226872\\nYou are entitled to receive a copy of any appraisal report that is obtained on your behalf, concerning your\\nsubject property, at least three business days prior to the closing of your loan. A copy of any and all such\\nappraisal reports (\\u201cappraisal report") should have already been delivered to you, allowing you at least\\nthree business days to review it prior to the closing of your loan.\\nIf you wish to proceed with the loan closing, your signature will acknowledge either:\\n1. Your receipt of the appraisal report three or more business days prior to your 
# ...

# %%
retriever = vectordb.as_retriever(search_kwargs={"k": 3})

# %%
retriever.search_type
# Out:
# 'similarity'

# %% [markdown]
# ## **Deleteing the DB**

# %%
# !zip -r db.zip ./db
# Out:
#   adding: db/ (stored 0%)
#   adding: db/chroma-embeddings.parquet (deflated 21%)
#   adding: db/index/ (stored 0%)
#   adding: db/index/index_add053f5-6624-4040-a6ba-e1b478d2dd67.bin (deflated 22%)
#   adding: db/index/id_to_uuid_add053f5-6624-4040-a6ba-e1b478d2dd67.pkl (deflated 36%)
#   adding: db/index/uuid_to_id_add053f5-6624-4040-a6ba-e1b478d2dd67.pkl (deflated 40%)
#   adding: db/index/index_metadata_add053f5-6624-4040-a6ba-e1b478d2dd67.pkl (deflated 14%)
#   adding: db/chroma-collections.parquet (deflated 50%)

# %%
# To cleanup, you can delete the collection
vectordb.delete_collection()
vectordb.persist()

# delete the directory
# !rm -rf db/

# %% [markdown]
# ## **Starting again loading the db**

# %%
# !unzip db.zip
# Out:
# Archive:  db.zip
#    creating: db/
#   inflating: db/chroma-embeddings.parquet
#    creating: db/index/
#   inflating: db/index/index_add053f5-6624-4040-a6ba-e1b478d2dd67.bin
#   inflating: db/index/id_to_uuid_add053f5-6624-4040-a6ba-e1b478d2dd67.pkl
#   inflating: db/index/uuid_to_id_add053f5-6624-4040-a6ba-e1b478d2dd67.pkl
#   inflating: db/index/index_metadata_add053f5-6624-4040-a6ba-e1b478d2dd67.pkl
#   inflating: db/chroma-collections.parquet

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings

from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA

# %%
from langchain.embeddings import HuggingFaceInstructEmbeddings

instructor_embeddings = HuggingFaceInstructEmbeddings(model_name="hkunlp/instructor-xl",
                                                      model_kwargs={"device": "cuda"})
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
persist_directory = 'db'
embedding = instructor_embeddings

vectordb2 = Chroma(persist_directory=persist_directory,
                  embedding_function=embedding,
                   )

retriever = vectordb2.as_retriever(search_kwargs={"k": 2})

# %%
docs = retriever.get_relevant_documents("Eleborate Right to Financial Privacy Act?")
docs[0]
# Out:
# Document(page_content='text: Eee\\nGENERAL DISCLOSURE NOTICE (APPLICABLE TO ALL APPLICANTS)\\nLoan #: 1522099444\\nServ. # 0182355941\\nMIN: 101418522072285021\\n| I/We the applicant(s) for a mortgage with Garden State Home Loans, Inc\\nfurther known as the "Lender" acknowledge the following information:\\n\\n1. In accordance with the "Right to Financial Privacy Act" of 1978, Public Law 93-579, I/we understand that\\nFHA, VA, Fannie Mae, the Lender, its agent and/or assigns, has a right of access to financial records held\\nby a financial institution in connection with the consideration or administration of assistance to me/us. I/We\\nfurther understand that financial records involving this transaction will be available to these agencies without\\nfurther notice or authorization, but will not be disclosed or released to another Government Agency or\\nDepartment without my/our consent except as required or permitted by law. I/We further acknowledge that\\nthe general purpose and use o
# ...
